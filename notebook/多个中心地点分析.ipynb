# %%
# -*- coding: utf-8 -*-
# %matplotlib inline


import pandas as pd
import geohash
import sqlite3 as sql
import datetime
import sys
import sqlalchemy
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from itertools import *
from pandas import ExcelWriter
from geopy.distance import vincenty


# Use chinese for MPL
mpl.rcParams['font.family'] = 'Hiragino Sans GB'
mpl.rcParams['font.sans-serif'] = 'Hiragino Sans GB'
mpl.rcParams['text.latex.unicode']=True

# %%
database_path = '../database/'
database_files = ['龙茗路顾戴路(2016-10-10)-data.db']
database_locations = ['龙茗路顾戴路']

# %%
# load database
def load_database(db_name):
    engine = sqlalchemy.create_engine('sqlite:///' + database_path + db_name)
    restaurants_db = pd.read_sql_table('restaurants', engine)
    menus_db = pd.read_sql_table('menus', engine)
    
    # 计算营业额
    menus_db['revenue'] = menus_db['price'] * menus_db['month_sales']
        
    # 合并到主数据库
    revenue_db = menus_db.loc[:, ['restaurant_id', 'revenue']].groupby('restaurant_id').sum().reset_index(drop=False)
    restaurants_db = pd.merge(restaurants_db, revenue_db, left_on='id', right_on='restaurant_id',how='left')
    
    # 计算菜单平均价
    mean_db = menus_db.loc[:, ['restaurant_id', 'price']].groupby('restaurant_id').mean().reset_index(
            drop=False).rename(columns={'price': 'mean_price'})
    restaurants_db = pd.merge(restaurants_db, mean_db, on='restaurant_id')

    # 计算平均价格
    restaurants_db['average_price'] = restaurants_db['revenue'] / restaurants_db['month_sales']

    restaurants_db['revenue'] = restaurants_db['revenue'].fillna(0)
#     del restaurants_db['restaurant_id']
    
    return restaurants_db
    

database_list =[]
for db_file in database_files:
    database_list.append(load_database(db_file))

# %%
num_records = 0
for db in database_list:
    num_records += db.shape[0]
print (num_records)
# Out:
# 1646

# %%
for db in database_list:
    print (db[db.name.str.contains('瓜牛')].loc[:,['name','restaurant_id','revenue']])
# Out:
# Empty DataFrame
# Columns: [name, restaurant_id, revenue]
# Index: []

# %%
# test_db_1 = database_list[0]
# print (test_db_1.shape[0], test_db_1.drop_duplicates('id').shape[0])
# test_db_2 = database_list[1]
# print (test_db_2.shape[0], test_db_2.drop_duplicates('id').shape[0])
# test_db_3 = database_list[2]
# print (test_db_3.shape[0], test_db_3.drop_duplicates('id').shape[0])

# print ('num_duplicates', test_db_1[test_db_1['id'].isin(test_db_2['id']) == False].shape[0])

# %%
# Merge
full_db = database_list[0]
for db in database_list[1:]:
    full_db = full_db.append(db)

    
full_db = full_db.sort_values('revenue',ascending=False).drop_duplicates(subset='id')
print (full_db.shape[0])
# Out:
# 1646

# %%
new_db = full_db.copy()
new_db.loc[2232,'revenue'] = 1500000
full_db = new_db

full_db.sort_values('revenue', ascending=False)
# Out:
#            id                     name     name_for_url  rating  rating_count  \
# 8089   974824                    帝王小龙虾           bzizja       4           492
# 7826   983095             新香小龙虾&鸿福港式烧腊           rnnjbi       4           419
# 2232   310846                 盒马（陆家嘴店）           ljz-hm       4         11205
# 7724  121.475929            False          15.0                 150.0
# 5310  121.529536            False           5.0                  20.0
#
#       minimum_free_delivery_amount  \
# 8089                           0.0
# 7826                           0.0
# 2232                           0.0
# 5653                           0.0
# 5797                           0.0
# 1112                           0.0
# 3887                           0.0
# 4993                           0.0
# 2176                           0.0
# 3915                           0.0
# 127                            0.0
# 5986                           0.0
# 2639                           0.0
# 139                            0.0
# 6811                           0.0
# 24                             0.0
# 2509                           0.0
# 1341                           0.0
# 4491                           0.0
# 4214                           0.0
# 4982                           0.0
# 753                            0.0
# 5320                           0.0
# 6188                           0.0
# 6860                           0.0
# 3586                           0.0
# 6950                           0.0
# 3524                           0.0
# 2144                           0.0
# 414                            0.0
# ...                            ...
# 7934                           0.0
# 7932                           0.0
# 3751                           0.0
# 7931                           0.0
# 7930                           0.0
# 7929                           0.0
# 7928                           0.0
# 7927                           0.0
# 6015                           0.0
# 7924                           0.0
# 7719                           0.0
# 3746                           0.0
# 3745                           0.0
# 6088                           0.0
# 6082                           0.0
# 7729                           0.0
# 7745                           0.0
# 7744                           0.0
# 7740                           0.0
# 6084                           0.0
# 7737                           0.0
# 7736                           0.0
# 3742                           0.0
# 7733                           0.0
# 3744                           0.0
# 7713                           0.0
# 7726                           0.0
# 7725                           0.0
# 7724                           0.0
# 5310                           0.0
#
#                                          promotion_info  \
# 8089  你好欢迎光临我们帝王小龙虾餐厅，有什么需要请与我们联系，用餐高峰期请你提前预定，以免耽误你的...
# 7826
# 2232  饿了么强势推荐，盒马外卖，互联网品牌，五星级餐饮品质，准时送达！\n电话：021-68902...
# 5653  饿了么强势推荐，盒马外卖，互联网品牌，五星级餐饮品质，准时送达！电话：61158312、13...
# 5797  A梦Eamonn's 杨浦（通北店）通北路888号,以时下最流行的创意菜为主线,食材新鲜，用...
# 1112  A梦餐廳Eamonn's 闸北(共新店)位于共和新路480号，晚市及夜宵堂吃爆款优惠活动，每...
# 3887  A梦餐廳Eamonn's 普陀（枣阳店)枣阳路259号，晚市及夜宵堂吃爆款优惠活动，每桌满8...
# 4993  饿了么强势推荐，盒马外卖，互联网品牌，五星级餐饮品质，准时送达！\n电话：021- 5589...
# 2176                                     请亲们正确详细的填写送餐地址
# 3915  Darling..世界辣么大，果然十分精彩。虽然很留恋。但我们更期待能即刻为您提供超有幸福感...
# 127   A梦餐廳Eamonn's 虹口(玉田店)位于玉田路511号，本餐厅所有食物为下单后现做，热炒...
# 5986                  街头霸王小龙虾  活动期间在本店下单10次      龙虾任选1份
# 2639  下单就送饮料，为了您能按时就餐，请您提前45分钟订餐！如遇雨天！请提前一个半小时订餐！不到之...
# 139   尊敬的顾客，优惠惊人，为了确保你能及时用餐，希望您能够提前1.5小时预定下单，避开高峰期，确...
# 6811                          欢迎添加瓜牛微信15021772764，活动多多~
# 24                                       干净卫生 送餐及时 服务稳定
# 3745                        马当路264号  0.000000e+00   419.435897       0.000000
# 6088          上海市闵行区虹桥镇莲花路2150弄23号甲  0.000000e+00    16.300000            NaN
# 6082                   上海市黄浦区会稽路35号  0.000000e+00    17.764706            NaN
# 7729                        芳草路377号  0.000000e+00    26.418750            NaN
# 7745                   上海市杨浦区靖宇南路2号  0.000000e+00     7.125000            NaN
# 7744             普陀区长寿路401号亚新后门全家后面  0.000000e+00    12.692308            NaN
# 7740                     上海市浦东新区北艾路  0.000000e+00    15.826087       0.000000
# 6084                         延平路98号  0.000000e+00    92.783913       0.000000
# 7737              上海市杨浦区辽源东路双阳路351号  0.000000e+00     9.966216            NaN
# 7736                     上海市黄浦区徐家汇路  0.000000e+00     8.000000            NaN
# 3742                        常德路631号  0.000000e+00   419.435897       0.000000
# 7733                  上海市黄浦区金陵东路67号  0.000000e+00     9.569444       0.000000
# 3744                       重庆北路167号  0.000000e+00   419.435897            NaN
# 7713                 上海市杨浦区武东路36号-2  0.000000e+00    21.910714       0.000000
# 7726                     上海市浦东新区崂山路  0.000000e+00    34.153846            NaN
# 7725               上海市杨浦区政立路国和路346号  0.000000e+00    12.592105            NaN
# 7724               上海市黄浦区武胜路富春路701号  0.000000e+00    35.692308       0.000000
# 5310                    浦东新区乳山路329号  0.000000e+00    10.833333            NaN
#
# [11613 rows x 18 columns]

# %%
# full_db.loc[2232]

# %%
# 嘉里中心
targets = { 
#     '嘉里中心':(31.224325,121.45036), 
#     '浦东国金':(31.2365804, 121.5010703), 
#     '新大陆广场':(31.2291802, 121.5180393),
#     '淮海香港广场':(31.2229601, 121.4752205),
#     '春城汉堡王':(31.1053198, 121.4114296)
    '龙茗路顾戴路':(31.13629, 121.38919)
}

with ExcelWriter('2000_metre.xlsx') as writer:
    for key,value in targets.items():
        full_db['distance'] = full_db.apply(lambda row: vincenty((row.latitude, row.longitude), value).km, axis=1)
        db = full_db[full_db.distance < 2]
        db = db[(db.name.str.contains('麻辣烫') 
                 | db.name.str.contains('香锅') 
                 | db.name.str.contains('冒菜')
                 | db.name.str.contains('烧烤')) == False]

        db = db.sort_values('revenue',ascending=False)
        print (key,'2KM内店家数量', db.shape[0])
        
        print (key,'营业额', db.revenue.sum())
        print (key,'平均单店', db.revenue.sum() / db.shape[0])
        
        head_db = db.head(50)
        head_db.to_excel(writer, key + '-revenue')
        
        db = db.sort_values('month_sales',ascending=False)
        print (key,'销量', db.month_sales.sum())
        print (key,'每单价值', db.revenue.sum() / db.month_sales.sum())
        
        
        head_db = db.head(50)
        head_db.to_excel(writer, key + '-monthsales')
# Out:
# 龙茗路顾戴路 2KM内店家数量 109
# 龙茗路顾戴路 营业额 3712240.1566666663
# 龙茗路顾戴路 平均单店 34057.249143730885
# 龙茗路顾戴路 销量 85924
# 龙茗路顾戴路 每单价值 43.20376328693574

# %%
db =
# Out:
#            name        revenue
# 6811   瓜牛（新天地店）  609620.000000
# 753    瓜牛（陆家嘴店）  549171.333333
# 5320  瓜牛（南京西路店）  534243.000000
# 7932   瓜牛（愚园路店）  107083.000000

# %%
group = full_db['revenue'].groupby(full_db['geohash'])
values = group.sum().sort_values(ascending=False).reset_index()
print(values.shape[0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/opt/pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1944             try:
# -> 1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'geohash'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-0c4a0c74871b> in <module>()
# ----> 1 group = full_db['revenue'].groupby(full_db['geohash'])
#       2 values = group.sum().sort_values(ascending=False).reset_index()
#       3 print(values.shape[0])
#
# /usr/local/opt/pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# /usr/local/opt/pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
#    2006         # duplicate columns & possible reduce dimensionality
#
# /usr/local/opt/pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1348         res = cache.get(item)
#    1349         if res is None:
# -> 1350             values = self._data.get(item)
#    1351             res = self._box_item_values(item, values)
#    1352             cache[item] = res
#
# /usr/local/opt/pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3288
#    3289             if not isnull(item):
# -> 3290                 loc = self.items.get_loc(item)
#    3291             else:
#    3292                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /usr/local/opt/pyenv/versions/anaconda3-4.1.1/lib/python3.5/site-packages/pandas/indexes/base.py in get_loc(self, key, method, tolerance)
#    1945                 return self._engine.get_loc(key)
#    1946             except KeyError:
# -> 1947                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    1948
#    1949         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4154)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:4018)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12368)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12322)()
#
# KeyError: 'geohash'

# %%
group = full_db['revenue'].groupby(full_db['geohash'])
values = group.sum().sort_values(ascending=False).head(10).reset_index()

with ExcelWriter('all_geohash.xlsx') as writer:
    for value in values['geohash']:
        records = full_db[full_db['geohash'] == value]
        records.to_excel(writer,value)

# %%
mean_db = full_db.loc[full_db['mean_price'] > 30].copy()
print(mean_db.shape[0])

mean_db.head(1)
# Out:
# 2148
#     id           name name_for_url  rating  rating_count  month_sales  \
# 3  389  行运港式茶餐厅（斜徐路店）   hp-xygscct       4           222          733
#
#       phone   latitude   longitude is_free_delivery  delivery_fee  \
# 3  63022877  31.206646  121.472554            False           5.0
#
#    minimum_order_amount  minimum_free_delivery_amount  \
# 3                  20.0                           0.0
#
#                                       promotion_info        address  revenue  \
# 3  由于今日运力紧张，起送价临时调整到30元，运力恢复时起送价将恢复到原先价格，此举为了保证服务...  斜徐路583号行运港式餐厅  10795.0
#
#    mean_price  average_price geohash
# 3   34.759184      14.727149  wtw3s0

# %%
group = mean_db['revenue'].groupby(mean_db['geohash'])
values = group.sum().sort_values(ascending=False).head(10).reset_index()

with ExcelWriter('30_geohash.xlsx') as writer:
    for value in values['geohash']:
        records = mean_db[mean_db['geohash'] == value]
        records.to_excel(writer,value)

    

#     print (records['name','address'])

# %%
mean_db = full_db.loc[full_db['mean_price'] > 50].copy()
print(mean_db.shape[0])

mean_db.head(1)
# Out:
# 743
#       id     name name_for_url  rating  rating_count  month_sales  \
# 53  5874  大胡子特色炒饭   xh-ahztssj       4          3575        14820
#
#                       phone   latitude   longitude is_free_delivery  \
# 53  13681930519 13024105871  31.160329  121.421669            False
#
#     delivery_fee  minimum_order_amount  minimum_free_delivery_amount  \
# 53           5.0                  20.0                           0.0
#
#                                        promotion_info  address   revenue  \
# 53  各位小主，本店优先配送饿了么，遇到恶劣天气送餐较慢，请多多担待哈！如果您的美食凉了，或者口味...  桂林路114号  161079.0
#
#     mean_price  average_price geohash
# 53       87.65      10.869028  wtw370

# %%
group = mean_db['revenue'].groupby(mean_db['geohash'])
values = group.sum().sort_values(ascending=False).head(10).reset_index()

with ExcelWriter('50_geohash.xlsx') as writer:
    for value in values['geohash']:
        records = mean_db[mean_db['geohash'] == value]
        records.to_excel(writer,value)
